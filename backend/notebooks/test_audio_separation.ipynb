# %%
from pathlib import Path

video_path = Path("../tests/videos/6.mp4")
output_dir = Path("./capture")
output_dir.mkdir(exist_ok=True)

# %%
import ffmpeg
from audio_separator.separator import Separator
from pathlib import Path

audio_path = Path("../tests/videos/1.wav")
output_dir = Path("./output")
# ffmpeg.input(str(video_path)).output(str(audio_path)).run(overwrite_output=True)
separator = Separator(output_dir=str(output_dir), output_format="mp3")

separator.load_model("UVR-MDX-NET-Inst_HQ_3.onnx")
output_names = {
    # "Vocals": "audio_vocals",
    "Instrumental": "audio_bgm",
}
output_files = separator.separate(str(audio_path), output_names)
# Out:
# 2026-06-05 20:04:06,927 - INFO - separator - Separator version 0.44.2 instantiating with output_dir: output, output_format: mp3
# 2026-06-05 20:04:06,929 - INFO - separator - Using model directory from model_file_dir parameter: /tmp/audio-separator-models/
# 2026-06-05 20:04:06,931 - INFO - separator - Operating System: Windows 10.0.26100
# 2026-06-05 20:04:06,932 - INFO - separator - System: Windows Node: LAPTOP-CN9D0PCU Release: 11 Machine: AMD64 Proc: AMD64 Family 26 Model 36 Stepping 0, AuthenticAMD
# 2026-06-05 20:04:06,933 - INFO - separator - Python Version: 3.12.11
# 2026-06-05 20:04:06,934 - INFO - separator - PyTorch Version: 2.12.0+cpu
# 2026-06-05 20:04:06,979 - INFO - separator - FFmpeg installed: ffmpeg version 7.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
# 2026-06-05 20:04:06,984 - INFO - separator - ONNX Runtime CPU package installed with version: 1.26.0
# 2026-06-05 20:04:06,986 - INFO - separator - No hardware acceleration could be configured, running in CPU mode
# 2026-06-05 20:04:06,987 - INFO - separator - Loading model UVR-MDX-NET-Inst_HQ_3.onnx...
# 100%|██████████| 66.8M/66.8M [00:03<00:00, 19.1MiB/s]
# 2026-06-05 20:04:11,670 - INFO - separator - Hash of model file /tmp/audio-separator-models/UVR-MDX-NET-Inst_HQ_3.onnx is 55657dd70583b0fedfba5f67df11d711
# 4.38kiB [00:00, 2.19MiB/s]
# 15.4kiB [00:00, 7.67MiB/s]
# 2026-06-05 20:04:16,652 - INFO - separator - Load model duration: 00:00:09
# 2026-06-05 20:04:16,653 - INFO - separator - Processing file: ..\tests\videos\1.wav
# 2026-06-05 20:04:16,653 - INFO - separator - Starting separation process for audio_file_path: ..\tests\videos\1.wav
# 2026-06-05 20:04:16,665 - INFO - common_separator - Input audio subtype: PCM_16
# 2026-06-05 20:04:16,667 - INFO - common_separator - Detected input bit depth: 16-bit
# 100%|██████████| 8/8 [00:14<00:00,  1.86s/it]
# 100%|██████████| 7/7 [00:00<00:00, 11.75it/s]
# 2026-06-05 20:04:33,602 - INFO - mdx_separator - Saving Vocals stem to 1_(Vocals)_UVR-MDX-NET-Inst_HQ_3.mp3...
# 2026-06-05 20:04:33,711 - INFO - common_separator - Audio duration is 0.01 hours (30.79 seconds).
# 2026-06-05 20:04:33,712 - INFO - common_separator - Using pydub for writing.
# 2026-06-05 20:04:33,722 - INFO - common_separator - Writing output with 16-bit depth
# 2026-06-05 20:04:34,251 - INFO - mdx_separator - Saving Instrumental stem to audio_bgm.mp3...
# 2026-06-05 20:04:34,268 - INFO - common_separator - Audio duration is 0.01 hours (30.79 seconds).
# 2026-06-05 20:04:34,269 - INFO - common_separator - Using pydub for writing.
# 2026-06-05 20:04:34,278 - INFO - common_separator - Writing output with 16-bit depth
# 2026-06-05 20:04:35,078 - INFO - common_separator - Clearing input audio file paths, sources and stems...
# 2026-06-05 20:04:35,082 - INFO - separator - Separation duration: 00:00:18

# %%
output_files
# Out:
# ['1_(Vocals)_UVR-MDX-NET-Inst_HQ_3.mp3', 'audio_bgm.mp3']

# %% [markdown]
# ## differentiate different instruments

# %%
import ffmpeg
from audio_separator.separator import Separator
from pathlib import Path

output_dir = Path("./output")
audio_path = Path("../tests/videos/1.wav")
separator = Separator(output_dir=str(output_dir), output_format="mp3")

model_name = "htdemucs_ft.yaml"
separator.load_model(model_name)
output_files = separator.separate(str(audio_path), output_names)
# Out:
# 2026-06-05 20:03:15,425 - INFO - separator - Separator version 0.44.2 instantiating with output_dir: output, output_format: mp3
# 2026-06-05 20:03:15,426 - INFO - separator - Using model directory from model_file_dir parameter: /tmp/audio-separator-models/
# 2026-06-05 20:03:15,428 - INFO - separator - Operating System: Windows 10.0.26100
# 2026-06-05 20:03:15,431 - INFO - separator - System: Windows Node: LAPTOP-CN9D0PCU Release: 11 Machine: AMD64 Proc: AMD64 Family 26 Model 36 Stepping 0, AuthenticAMD
# 2026-06-05 20:03:15,432 - INFO - separator - Python Version: 3.12.11
# 2026-06-05 20:03:15,433 - INFO - separator - PyTorch Version: 2.12.0+cpu
# 2026-06-05 20:03:15,475 - INFO - separator - FFmpeg installed: ffmpeg version 7.1-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
# 2026-06-05 20:03:15,479 - INFO - separator - ONNX Runtime CPU package installed with version: 1.26.0
# 2026-06-05 20:03:15,480 - INFO - separator - No hardware acceleration could be configured, running in CPU mode
# 2026-06-05 20:03:15,482 - INFO - separator - Loading model htdemucs_ft.yaml...
# 28.3kiB [00:00, 8.31MiB/s]
# 100%|██████████| 84.1M/84.1M [00:03<00:00, 21.4MiB/s]
# 100%|██████████| 84.1M/84.1M [00:03<00:00, 21.8MiB/s]
#  51%|█████     | 42.7M/84.1M [00:02<00:02, 19.9MiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       6 audio_path = Path("../tests/videos/1.wav")
#       7 separator = Separator(output_dir=str(output_dir), output_format="mp3")
#       8
#       9 model_name = "htdemucs_ft.yaml"
# ---> 10 separator.load_model(model_name)
#      11 output_files = separator.separate(str(audio_path), output_names)
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\audio_separator\separator\separator.py:855, in Separator.load_model(self, model_filename)
#     852 load_model_start_time = time.perf_counter()
#     854 # Setting up the model path
# --> 855 model_filename, model_type, model_friendly_name, model_path, yaml_config_filename = self.download_model_files(model_filename)
#     856 model_name = model_filename.split(".")[0]
#     857 self.logger.debug(f"Model downloaded, friendly name: {model_friendly_name}, model_path: {model_path}")
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\audio_separator\separator\separator.py:728, in Separator.download_model_files(self, model_filename)
#     726     filename = file_to_download.split("/")[-1]
#     727     download_path = os.path.join(self.model_file_dir, filename)
# --> 728     self.download_file_if_not_exists(file_to_download, download_path)
#     729     continue
#     731 download_path = os.path.join(self.model_file_dir, file_to_download)
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\audio_separator\separator\separator.py:508, in Separator.download_file_if_not_exists(self, url, output_path)
#     505 progress_bar = tqdm(total=total_size_in_bytes, unit="iB", unit_scale=True)
#     507 with open(output_path, "wb") as f:
# --> 508     for chunk in response.iter_content(chunk_size=8192):
#     509         progress_bar.update(len(chunk))
#     510         f.write(chunk)
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\requests\models.py:937, in Response.iter_content.<locals>.generate()
#     935 if hasattr(self.raw, "stream"):
#     936     try:
# --> 937         yield from self.raw.stream(chunk_size, decode_content=True)
#     938     except ProtocolError as e:
#     939         raise ChunkedEncodingError(e)
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\urllib3\response.py:1267, in HTTPResponse.stream(self, amt, decode_content)
#    1261 else:
#    1262     while (
#    1263         not is_fp_closed(self._fp)
#    1264         or len(self._decoded_buffer) > 0
#    1265         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1266     ):
# -> 1267         data = self.read(amt=amt, decode_content=decode_content)
#    1269         if data:
#    1270             yield data
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\urllib3\response.py:1110, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1107     if len(self._decoded_buffer) >= amt:
#    1108         return self._decoded_buffer.get(amt)
# -> 1110 data = self._raw_read(amt)
#    1111 if not cache_content:
#    1112     self._uncached_read_occurred = True
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\urllib3\response.py:1022, in HTTPResponse._raw_read(self, amt, read1)
#    1019 fp_closed = getattr(self._fp, "closed", False)
#    1021 with self._error_catcher():
# -> 1022     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1023     if amt is not None and amt != 0 and not data:
#    1024         # Platform-specific: Buggy versions of Python.
#    1025         # Close the connection when no data is returned
#    (...)   1030         # not properly close the connection in all cases. There is
#    1031         # no harm in redundantly calling close.
#    1032         self._fp.close()
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\urllib3\response.py:1005, in HTTPResponse._fp_read(self, amt, read1)
#    1002     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1003 else:
#    1004     # StringIO doesn't like amt=None
# -> 1005     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File D:\AppData\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File D:\AppData\uv\python\cpython-3.12-windows-x86_64-none\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File D:\AppData\uv\python\cpython-3.12-windows-x86_64-none\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File D:\AppData\uv\python\cpython-3.12-windows-x86_64-none\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
