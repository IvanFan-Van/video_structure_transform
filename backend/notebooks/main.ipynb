# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

try:
    # 发起对话请求
    completion = client.chat.completions.create(
        # 注意：这里必须填入你的 Endpoint ID (EP)
        model=os.getenv("MODEL", ""),
        messages=[
            {"role": "system", "content": "你是一个乐于助人的 AI 助手。"},
            {"role": "user", "content": "你好，请问你是谁？"},
        ],
        temperature=0.7,
    )

    # 打印返回结果
    print(completion.choices[0].message.content)

except Exception as e:
    print(f"调用失败，错误信息: {e}")
# Out:
# 你好呀😊我是由字节跳动公司独立开发的人工智能助手豆包~
#
# 我可以帮你做很多事哦：不管是解答各类知识疑问、整理信息思路，还是帮你写文案/出创意点子、闲聊唠嗑打发时间，甚至是找旅行攻略、美食推荐、做学习辅助都完全没问题，你有任何想法需求都可以随时和我说呀😉
