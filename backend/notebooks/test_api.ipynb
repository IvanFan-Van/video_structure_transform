# %% [markdown]
# ## Test API KEY working

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path

from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ## Text Response

# %%
from openai import OpenAI

client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

SYSTEM_PROMPT = """You are a helpful assistant"""
QUERY = "What is the capital of France?"

try:
    # 发起对话请求
    completion = client.chat.completions.create(
        # 注意：这里必须填入你的 Endpoint ID (EP)
        model=os.getenv("MODEL", ""),
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": QUERY},
        ],
        # 传输视频
        temperature=0.7,
    )

    # 打印返回结果
    print(completion.choices[0].message.content)

except Exception as e:
    print(f"调用失败，错误信息: {e}")
# Out:
# The capital of France is **Paris**.
#
# Situated along the banks of the Seine River in the northern half of the country, Paris is not just France's administrative and political center, but also its core hub for culture, economy, art, and world-renowned gastronomy. It is one of the most visited cities on the planet, famous for iconic landmarks including the Eiffel Tower, the Louvre Museum (home to the Mona Lisa), Notre-Dame Cathedral, its tree-lined historic boulevards, and classic Parisian sidewalk cafes.

# %% [markdown]
# ## Video Input

# %%
import os
import sys
from pathlib import Path
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(), override=True)

sys.path.append(str(Path(os.getcwd()).parent))

# %%
from openai import OpenAI
from pathlib import Path
from src.video import VideoClip

input_path = Path("../tests/videos/抖音2026529-207530.mp4")
output_path = Path("../tests/videos/抖音2026529-207530_output.mp4")

video = VideoClip(input_path)
compressed_video = video.compress(output_path)

print("video info")
print(video)

print("compressed video info")
print(compressed_video)
# Out:
# Video Compressed Successfully: D:\HKU\video_structure_transform\backend\tests\videos\抖音2026529-207530_output.mp4
# video info
# Video Path: D:\HKU\video_structure_transform\backend\tests\videos\抖音2026529-207530.mp4
# Codec: h264
# Resolution: 1280x720
# FPS: 30.0
# Video Bitrate: 400 kbps
# Total Bitrate: 538 kbps
# Audio Sample Rate: 44100 Hz
# Audio Channels: 2
# Audio Bitrate: 128 kbps
# compressed video info
# Video Path: D:\HKU\video_structure_transform\backend\tests\videos\抖音2026529-207530_output.mp4
# Codec: h264
# Resolution: 1280x720
# FPS: 30.0
# Video Bitrate: 310 kbps
# Total Bitrate: 414 kbps
# Audio Sample Rate: 44100 Hz
# Audio Channels: 2
# Audio Bitrate: 94 kbps

# %%
client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

# %%
import time

starttime = time.time()

file = client.files.create(
    file=open(output_path, "rb"),
    purpose="user_data",
)
print(file)

# file = client.files.delete(file_id=file.id)
# print(file)

print(f"上传视频耗时: {time.time() - starttime:.2f} 秒")
# Out:
# FileObject(id='file-20260529181511-zvsln', bytes=1042538, created_at=1780049711, filename='抖音2026529-207530_output.mp4', object='file', purpose='user_data', status='processing', expires_at=None, status_details=None, mime_type='video/mp4', expire_at=1780654511)
# 上传视频耗时: 31.25 秒

# %%
starttime = time.time()

file = client.files.create(
    file=open(input_path, "rb"),
    purpose="user_data",
)
print(file)

file = client.files.delete(file_id=file.id)
print(file)

print(f"上传视频耗时: {time.time() - starttime:.2f} 秒")
# Out:
# FileObject(id='file-20260529180617-pctzz', bytes=10878955, created_at=1780049177, filename='抖音2026528-272271.mp4', object='file', purpose='user_data', status='processing', expires_at=None, status_details=None, mime_type='video/mp4', expire_at=1780653977)
# FileDeleted(id='file-20260529180617-pctzz', deleted=True, object='file')
# 上传视频耗时: 247.68 秒

# %%
from openai import OpenAI

client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

QUERY = "我想复刻这个视频, 请总结一下这个视频的风格和内容"

try:
    # 发起对话请求
    completion = client.chat.completions.create(
        # 注意：这里必须填入你的 Endpoint ID (EP)
        model=os.getenv("MODEL", ""),
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "video_url",
                        "video_url": {
                            "url": f"data:video/mp4;base64,{video.to_base64()}"
                        },
                    },
                    {"type": "text", "text": QUERY},
                ],
            },  # type: ignore
        ],
        # 传输视频
        temperature=0.2,
    )

    # 打印返回结果
    print(completion.choices[0].message.content)

except Exception as e:
    print(f"调用失败，错误信息: {e}")
# Out:
# ### 内容总结
# 这是典型的反套路整活向短视频：开篇用氛围感文字抛出问题「什么东西比10亿更有价值？」，先铺垫大众常规认知里的高价值事物——友谊、时光、自由，刻意营造出要输出人生哲理的鸡汤氛围，随后用“一个傻子回答道”做强反转，跳出所有常规思路给出荒诞直白的答案：11亿，后续快速闪过11项具象的美好高价值事物，最终反复强调“11亿>10亿”，用完全不讲大道理的无厘头逻辑消解了鸡汤感，制造出强烈的反差搞笑效果。
#
# ### 风格总结
# 1.  视觉形式极简：全程没有实景画面，完全靠动态文字排版呈现内容，以纯黑/纯白为基底，仅用少量红色高亮核心关键词，搭配文字发光、色彩错位故障的特效，视觉冲击力强，干净利落。
# 2.  叙事节奏短平快：靠“严肃哲理铺垫→完全意料之外的魔性反转”的设计，把正经鸡汤叙事扭转为脑洞玩梗的整活内容，荒诞洗脑，是非常典型的互联网轻量化搞笑短视频风格，画面底部全程保留固定的“wuqr”标识水印。

# %%
from openai import OpenAI

client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

QUERY = "我想复刻这个视频, 请总结一下这个视频的风格和内容"

try:
    # 发起对话请求
    completion = client.chat.completions.create(
        # 注意：这里必须填入你的 Endpoint ID (EP)
        model=os.getenv("MODEL", ""),
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "video_url",
                        "video_url": {
                            "url": f"data:video/mp4;base64,{compressed_video.to_base64()}"
                        },
                    },
                    {"type": "text", "text": QUERY},
                ],
            },  # type: ignore
        ],
        # 传输视频
        temperature=0.2,
    )

    # 打印返回结果
    print(completion.choices[0].message.content)

except Exception as e:
    print(f"调用失败，错误信息: {e}")
# Out:
# ### 视频内容总结
# 这是一个反套路脑洞玩梗短视频：
# 1.  开篇先抛出设问「什么东西比10亿更有价值？」，先顺着大众常规认知，铺垫展示了大众普遍认为比金钱珍贵的非物质选项：友谊、时光、自由，后续还补充列举了靠谱知己、坦荡本心、平安顺遂等抒情向的珍贵人生事物，引导观众往“非物质美好比巨额财富更贵重”的鸡汤思路走。
# 2.  随后立刻反转解构鸡汤逻辑，借“一个傻子的回答”抛出完全意料之外的直白答案——11亿，反复用文字强调「11亿>10亿」的简单数值碾压逻辑，用完全不绕弯的荒诞反差制造喜剧笑点。
#
# ---
#
# ### 视频风格总结
# 这是纯动态文字创意类短视频，全程没有实景画面：
# 整体采用极简高对比的黑底白字暗黑酷感风格，关键核心文字（比如“傻子”、“11亿”）用红色高亮突出，还加入了复古信号故障的彩条错位特效强化视觉冲击力，节奏紧凑利落，画面底部全程保留固定的“wuqr”标识，属于典型的网络反鸡汤脑洞玩梗短视频，用极低的信息成本制造出强烈的预期反差，简洁又有记忆点。

# %%
from openai import OpenAI

client = OpenAI(
    # 火山引擎的 API Key，对应你截图中的 api-key
    api_key=os.getenv("API_KEY", ""),
    # 火山引擎的官方 OpenAI 兼容接入地址
    base_url=os.getenv("BASE_URL", ""),
)

QUERY = "我想复刻这个视频, 请总结一下这个视频的风格和内容"

try:
    # 发起对话请求
    response = client.responses.create(
        # 注意：这里必须填入你的 Endpoint ID (EP)
        model=os.getenv("MODEL", ""),
        input=[
            {
                "role": "user",
                "content": [
                    {"type": "input_video", "file_id": file.id},
                    {"type": "input_text", "text": QUERY},
                ],
            },  # type: ignore
        ],
        # 传输视频
        temperature=0.2,
    )

except Exception as e:
    print(f"调用失败，错误信息: {e}")

# %%
response.output
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 response.outputresponse
#
# File d:\HKU\video_structure_transform\backend\.venv\Lib\site-packages\pydantic\main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Response' object has no attribute 'outputresponse'
